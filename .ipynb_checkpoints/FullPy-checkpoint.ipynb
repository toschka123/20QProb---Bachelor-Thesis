# %%
# %load_ext ipython_sparql_pandas
from SPARQLWrapper import SPARQLWrapper, JSON
sparql = SPARQLWrapper('http://DESKTOP-CELL0BF:7200/repositories/20qsmall')
sparql.setReturnFormat(JSON)

# %%
#from the query results extract a list that contains the counts after splitting on certain attributes
import re
PosAttr=['?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .', '?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.']
NegAttr=[]
AttrHistory = ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>']

def prepareProps(popEntities):
    Distribution = {}
    for i in popEntities:
        Distribution[i]= 1/len(popEntities)
    return Distribution


def extractCountAndAttr(result):
    number = []
    listOfObj = []
    listOfPred= []
    for attr in result["results"]["bindings"]:
        listOfObj.append(attr['o'])
        listOfPred.append(attr['p'])
    #print(listOfObj[0])
    return(listOfObj,listOfPred)


  
def updateQuery(left, PosFilters, NegFilters):
    FilterQuestion =  (f"""
            select (count(*) as ?count) ?p ?o  where 
            {{
            {PosFilters}
             # ?s ?p ?o .
            {NegFilters}
            }} 
            group by ?p ?o 
            ORDER BY ABS( {left/2} - ?count )
            """) 
        
    return FilterQuestion

# %%
def numberleft(PosFilters,NegFilters):
    query =  f"""
            select (count(?s) as ?count) where 
            {{
            # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
            # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.
            {PosFilters}{NegFilters} 
          }}       
            group by ?p ?o 
            ORDER BY DESC(?count )            
            """ 
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    for r in qres["results"]["bindings"]:
        left= (r["count"]["value"])
        return(int(left))
    
def popentities(PosFilters,NegFilters):
    query =  f"""
            select ?s where 
            {{
            # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
            # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.
            {PosFilters}
            {NegFilters} 
            }}
            """ 
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert()
    results = []
    for r in qres["results"]["bindings"]:
        results.append(r["s"]["value"])
    return results

# %%
# resets are variables
def game_reset():
    left = numberleft("","")
    FilterQuestion = updateQuery(left, "","")
    sparql.setQuery(FilterQuestion)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert()
    listOfObj ,listOfPred = extractCountAndAttr(qres)
    return (left, qres, PosAttr, NegAttr, AttrHistory)

# %%
def prepareProps(popEntities):
    Distribution = {}
    for i in popEntities:
        Distribution[i] = 1
        #Distribution[i]= 1/len(popEntities)
    return Distribution
    

def findPosAndNeg(listOfObj, listOfPred, index):
    Filter = '?s <' + str(listOfPred[index]) +'> <'+str(listOfObj[index])+ '>.'
    negFilter='FILTER NOT EXISTS {{ \n ?s <' + str(listOfPred[index]) +'> <'+str(listOfObj[index])+ '>. }}'
    EntitiesPositive = popentities(Filter, "")
    EntitiesNegative = popentities("", negFilter)
    return (EntitiesPositive, EntitiesNegative)
    
                       
def findSplits():
    possibleObj=[]
    possiblePred =[]
    count = []
    query =  f"""
            select (count(?s) as ?count)   ?o ?p
            {{               
        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.
        # ?s ?p ?o.
            }}
        group by  ?o ?p
        ORDER BY desc ( ?count )
            """ 
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    for r in qres["results"]["bindings"]:
        possibleObj.append(r["o"]["value"])
        possiblePred.append(r["p"]["value"])
        count.append(r["count"]["value"])
   
    return (possibleObj, possiblePred, count)

def determineBestSplit(possibleObj, possiblePred, count):
    bestSplit=-1
    indexBestSplit = -1
    #branches = range(2,250)
    #for i in random.sample(branches, 40): 
    for i in range(350):
        #Fix The nummerical thing here::: (skip over i if nummer)
        if str('<' + str(possiblePred[i]) +'> <'+str(possibleObj[i])+ '>') in AttrHistory:
            continue
        else:
            Yes = pos.get(str('<' + str(possiblePred[i]) +'> <'+str(possibleObj[i])+ '>'))
            No = negs.get(str('<' + str(possiblePred[i]) +'> <'+str(possibleObj[i])+ '>'))
            OccurenceYes = len(Yes)
            OccurenceNo=len(No)
            """Yes, No = findPosAndNeg(possibleObj, possiblePred, i)
            OccurenceYes=len(Yes)
            OccurenceNo=len(No)"""
            WeightYes=0
            WeightNo=0
            for y in Yes:
                WeightYes+=Distribution[y]
            for n in No:
                WeightNo+=Distribution[n]
            SumWeights=WeightYes+WeightNo
            ProbabilityYes=WeightYes/SumWeights
            ProbabilityNo=WeightNo/SumWeights
            Entropy = - (ProbabilityYes * math.log(ProbabilityYes+0.0001,2) + ProbabilityNo * math.log(ProbabilityNo+0.0001,2))
            #print(str(possiblePred[i]) +'> <'+str(possibleObj[i]), Entropy)
            if Entropy > bestSplit:
                bestSplit=Entropy
                indexBestSplit=i
    #print(bestSplit, possibleObj[indexBestSplit], possiblePred[indexBestSplit])
    return(indexBestSplit, bestSplit)

def WrongAnswerRate(answer, chance):
    if randint(0,100)<chance:
        print("haha fooled!")
        if answer:
            answer=False
        else:
            answer=True
    return(answer)
        
def wrongAnswerList( amount):
    l = []
    i = -1
    for i in range(20-amount):
        l.append(True)
    for i in range(amount):
        l.append(False)
    random.shuffle(l)
    return(l, i)

def retrieveAnswer(answer, l, i):
    i+=1
    if l[i]:
        return(answer, i)
    else:
        print("wrong answer incoming")
        return(not answer, i)
"""preparePops
enter loop
find splits, determine best split, generate question (update probabilities)"""
# Out:
# 'preparePops\nenter loop\nfind splits, determine best split, generate question (update probabilities)'

# %%
def generateHumanQuestion(listOfObj, listOfPred, index, subject, Distribution):
    
    AttrHistory.append('<' + str(listOfPred[index]) +'> <'+str(listOfObj[index])+ '>')
    answer = input(f'Does the thing you are looking for have the attribute: {listOfPred[index].split("/")[-1]} {listOfObj[index].split("/")[-1]}?' )
    
    Yes, No = findPosAndNeg(listOfObj, listOfPred, index)
    if answer.startswith('y'):   
        for y in Yes:
            Distribution[y]= Distribution[y]*0.8
        for n in No:
            Distribution[n]= Distribution[n]*0.2
            
    else:
        for y in Yes:
            Distribution[y] = Distribution[y]*0.2
        for n in No:
            Distribution[n] = Distribution[n]*0.8
            
    print(Distribution[subject[1:-1]])
    return Distribution

def allSubjects(qres, ind):
    for r in qres["results"]["bindings"][ind:ind+1]:
        return("<"+r["s"]["value"]+">")

def loadSubjects():

    query = f"""
    select distinct ?s
    where {{
        # ?s ?p ?o .
        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity> .
        # ?s <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://yago-knowledge.org/resource/Human>.
    }}
    """
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    return qres
    
def pickSubject(qres):
    ind=randint(0,134)
    for r in qres["results"]["bindings"][ind:ind+1]:
        return("<"+r["s"]["value"]+">")

def findAnswer(subject,p,o):
    query = f"""
        SELECT ?s ?p ?o
        WHERE {{
        # ?s ?p ?o .
            FILTER(?s = {subject})
            FILTER(?p = {p})
            FILTER(?o = {o})
            }}
            """
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    qres = sparql.query().convert() 
    res = qres["results"]["bindings"]
    return (len(res))>0

# %%
def generateBotQuestionManipulate(listOfObj, listOfPred, index, subject, Distribution,itteration):
    AttrHistory.append('<' + str(listOfPred[index]) +'> <'+str(listOfObj[index])+ '>')
    print(f'Does the thing you are looking for have the attribute: {listOfPred[index].split("/")[-1]} {listOfObj[index].split("/")[-1]}?' )
    answer = findAnswer(subject, '<' + str(listOfPred[index]) +'>', '<'+str(listOfObj[index])+ '>')
    """if itteration in [17,18,19]:
        answer = not answer"""
    #answer = WrongAnswerRate(answer, 10)

    answer, initilaizeCount = retrieveAnswer(answer, answerPattern,i-1)
    print(answer)
    Yes, No = findPosAndNeg(listOfObj, listOfPred, index)
    """OccurenceYes=len(Yes)
    OccurenceNo=len(No)
    NEntities=OccurenceYes+OccurenceNo
    ProbabilityYes=OccurenceYes/NEntities
    ProbabilityNo=OccurenceNo/NEntities"""

    if answer:   
        for y in Yes:
            Distribution[y]= Distribution[y]*0.9
        for n in No:
            Distribution[n]= Distribution[n]*0.1
            
    else:
        for y in Yes:
            Distribution[y] = Distribution[y]*0.1
        for n in No:
            Distribution[n] = Distribution[n]*0.9
            
    print(Distribution[subject[1:-1]])
    return Distribution

# %%
def loadAllAttributes(possibleObj,possiblePred):
    EntsPerAttribute={}
    EntsWithoutAttribute={}
    for i in range(350):
        Yes, No = findPosAndNeg(possibleObj, possiblePred, i)

        attr=str('<' + str(possiblePred[i]) +'> <'+str(possibleObj[i])+ '>')
        EntsPerAttribute[attr]=Yes
        EntsWithoutAttribute[attr]=No
    return(EntsPerAttribute, EntsWithoutAttribute)


"""possibleObj, possiblePred, count = findSplits()
pos, negs= loadAllAttributes(possibleObj,possiblePred)"""
# Out:
# 'possibleObj, possiblePred, count = findSplits()\npos, negs= loadAllAttributes(possibleObj,possiblePred)'

# %%
#without printing results
from random import randint
import random
import math
import time 
wincount = 0
gamesplayed = 0
wrongAnswersPerQuestion = 3
totalgames = 134
Entrop_over_game = []
list_losses=[]
list_wins=[]

possibleObj, possiblePred, count = findSplits()
pos,negs = loadAllAttributes(possibleObj,possiblePred)
qres = loadSubjects()

while gamesplayed < totalgames:
    answerPattern, initilaizeCount = wrongAnswerList(wrongAnswersPerQuestion)
    Entropies=[]
    AttrHistory= ['<http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.com/popularEntity>']
    # Resets all variables
    i=0
    outofguess = []
    # pick subject
    #subject = pickSubject(qres)
    subject = allSubjects(qres, gamesplayed)
    print("\n" , subject)
    popularEntities =  popentities("\n".join(PosAttr),"")
    Distribution = prepareProps(popularEntities)
    
    while i < 20:

        # list of Pred and Obj for questions
        #listOfObj ,listOfPred = extractCountAndAttr(qres)

        # if only 1 popular entity is left break


        # ask question and add filters to query
        print('Question: %s' %(i+1))

        indexSplit, Entropy=determineBestSplit(possibleObj, possiblePred, count)
        Distribution = generateBotQuestionManipulate(possibleObj, possiblePred, indexSplit,subject, Distribution, i)
        i+=1
        Entropies.append(Entropy)
    # Prints answer
    #print(Distribution)
    highProb=-1
    for j in Distribution.values():
        if j > highProb:
            highProb=j
    answer = list(Distribution.keys())[list(Distribution.values()).index(highProb)]
    print("The Answer is: ", answer, "With a Probability of: ", highProb)
    print(subject)
    if str(answer.split("/")[-1] + ">") == str(subject.split("/")[-1]):
        wincount +=1
        #list_wins.append(answerPattern)
    #else:
        
        #list_losses.append(answerPattern)
    gamesplayed+=1
    Entrop_over_game.append(Entropies)
    time.sleep(0.5)
    
print("\nTournament ended! I have guessed " + str(wincount) + " out of " + str(gamesplayed) + " things correctly.")
# Out:
#  <http://yago-knowledge.org/resource/David_Bowie>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# 0.9
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# 0.81
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_States?
# False
# 0.7290000000000001
# Question: 4
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# True
# 0.6561000000000001
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# wrong answer incoming
# True
# 0.06561000000000002
# Question: 6
# Does the thing you are looking for have the attribute: award Theatre_World_Award?
# False
# 0.05904900000000002
# Question: 7
# Does the thing you are looking for have the attribute: award Academy_Award_for_Best_Actress?
# False
# 0.05314410000000002
# Question: 8
# Does the thing you are looking for have the attribute: birthPlace Westminster?
# False
# 0.04782969000000002
# Question: 9
# Does the thing you are looking for have the attribute: award BIFA_Award_for_Best_Performance_by_an_Actor_in_a_British_Independent_Film?
# False
# 0.043046721000000024
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# True
# 0.03874204890000002
# Question: 11
# Does the thing you are looking for have the attribute: award Grammy_Lifetime_Achievement_Award?
# True
# 0.03486784401000002
# Question: 12
# Does the thing you are looking for have the attribute: birthPlace Brixton?
# True
# 0.03138105960900001
# Question: 13
# Does the thing you are looking for have the attribute: award 100_Greatest_Britons?
# True
# 0.028242953648100012
# Question: 14
# Does the thing you are looking for have the attribute: award Rolling_Stone's_100_Greatest_Artists_of_All_Time?
# True
# 0.025418658283290013
# Question: 15
# Does the thing you are looking for have the attribute: spouse Iman_(model)?
# True
# 0.022876792454961013
# Question: 16
# Does the thing you are looking for have the attribute: givenName David_(name)?
# True
# 0.020589113209464913
# Question: 17
# Does the thing you are looking for have the attribute: children Duncan_Jones?
# True
# 0.01853020188851842
# Question: 18
# Does the thing you are looking for have the attribute: alumniOf Ravensbourne_University_London?
# wrong answer incoming
# False
# 0.0018530201888518423
# Question: 19
# Does the thing you are looking for have the attribute: familyName Bowie_(surname)?
# True
# 0.001667718169966658
# Question: 20
# Does the thing you are looking for have the attribute: familyName Jones_(surname)?
# wrong answer incoming
# False
# 0.00016677181699666582
# The Answer is:  http://yago-knowledge.org/resource/David_Bowie With a Probability of:  0.00016677181699666582
# <http://yago-knowledge.org/resource/David_Bowie>
#
#  <http://yago-knowledge.org/resource/Kanye_West>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# 0.9
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# 0.81
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 0.7290000000000001
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# 0.6561000000000001
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 0.5904900000000002
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# wrong answer incoming
# True
# 0.05904900000000002
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Guitarist?
# False
# 0.05314410000000002
# Question: 8
# Does the thing you are looking for have the attribute: award MTV_Video_Music_Award_for_Best_Female_Video?
# False
# 0.04782969000000002
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# True
# 0.043046721000000024
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Businessperson?
# True
# 0.03874204890000002
# Question: 11
# Does the thing you are looking for have the attribute: award Grammy_Award_for_Best_Rap%2FSung_Performance?
# True
# 0.03486784401000002
# Question: 12
# Does the thing you are looking for have the attribute: homeLocation Hidden_Hills,_California?
# True
# 0.03138105960900001
# Question: 13
# Does the thing you are looking for have the attribute: award BET_Award_for_Best_Group?
# True
# 0.028242953648100012
# Question: 14
# Does the thing you are looking for have the attribute: award BET_Award_for_Best_Male_Hip-Hop_Artist?
# True
# 0.025418658283290013
# Question: 15
# Does the thing you are looking for have the attribute: award Billboard_Music_Award_for_Top_Rap_Artist?
# True
# 0.022876792454961013
# Question: 16
# Does the thing you are looking for have the attribute: spouse Kim_Kardashian?
# True
# 0.020589113209464913
# Question: 17
# Does the thing you are looking for have the attribute: givenName Kanye_(name)?
# wrong answer incoming
# False
# 0.0020589113209464912
# Question: 18
# Does the thing you are looking for have the attribute: alumniOf American_Academy_of_Art?
# wrong answer incoming
# False
# 0.00020589113209464914
# Question: 19
# Does the thing you are looking for have the attribute: alumniOf Chicago_State_University?
# True
# 0.00018530201888518422
# Question: 20
# Does the thing you are looking for have the attribute: memberOf Child_Rebel_Soldier?
# True
# 0.00016677181699666582
# The Answer is:  http://yago-knowledge.org/resource/Kanye_West With a Probability of:  0.00016677181699666582
# <http://yago-knowledge.org/resource/Kanye_West>
#
#  <http://yago-knowledge.org/resource/Eminem>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# 0.9
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# True
# 0.81
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# 0.7290000000000001
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# wrong answer incoming
# True
# 0.0729
# Question: 5
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# 0.06561
# Question: 6
# Does the thing you are looking for have the attribute: nationality United_States?
# wrong answer incoming
# False
# 0.006561000000000001
# Question: 7
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# 0.005904900000000001
# Question: 8
# Does the thing you are looking for have the attribute: nationality Canada?
# wrong answer incoming
# True
# 0.0005904900000000002
# Question: 9
# Does the thing you are looking for have the attribute: givenName Charles?
# False
# 0.0005314410000000001
# Question: 10
# Does the thing you are looking for have the attribute: award MTV_Movie_Award_for_Best_On-Screen_Duo?
# False
# 0.0004782969000000001
# Question: 11
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# True
# 0.0004304672100000001
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Pianist?
# False
# 0.0003874204890000001
# Question: 13
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# True
# 0.00034867844010000006
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Guitarist?
# False
# 0.00031381059609000004
# Question: 15
# Does the thing you are looking for have the attribute: award Grammy_Award_for_Best_Rap%2FSung_Performance?
# True
# 0.00028242953648100003
# Question: 16
# Does the thing you are looking for have the attribute: hasOccupation Lyricist?
# True
# 0.00025418658283290005
# Question: 17
# Does the thing you are looking for have the attribute: birthPlace St._Joseph,_Missouri?
# True
# 0.00022876792454961005
# Question: 18
# Does the thing you are looking for have the attribute: homeLocation Warren,_Michigan?
# True
# 0.00020589113209464906
# Question: 19
# Does the thing you are looking for have the attribute: alumniOf University_of_Tennessee?
# True
# 0.00018530201888518417
# Question: 20
# Does the thing you are looking for have the attribute: familyName Mathers?
# True
# 0.00016677181699666576
# The Answer is:  http://yago-knowledge.org/resource/Eminem With a Probability of:  0.00016677181699666576
# <http://yago-knowledge.org/resource/Eminem>
#
#  <http://yago-knowledge.org/resource/Jennifer_Aniston>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# 0.9
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# wrong answer incoming
# False
# 0.09000000000000001
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 0.08100000000000002
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# 0.07290000000000002
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# True
# 0.06561000000000002
# Question: 6
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# True
# 0.05904900000000002
# Question: 7
# Does the thing you are looking for have the attribute: award Primetime_Emmy_Award_for_Outstanding_Lead_Actress_in_a_Comedy_Series?
# True
# 0.05314410000000002
# Question: 8
# Does the thing you are looking for have the attribute: birthPlace Oak_Park,_Illinois?
# False
# 0.04782969000000002
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Businessperson?
# True
# 0.043046721000000024
# Question: 10
# Does the thing you are looking for have the attribute: birthPlace Sherman_Oaks,_Los_Angeles?
# True
# 0.03874204890000002
# Question: 11
# Does the thing you are looking for have the attribute: homeLocation Bel_Air,_Los_Angeles?
# wrong answer incoming
# False
# 0.003874204890000002
# Question: 12
# Does the thing you are looking for have the attribute: award Golden_Globe_Award_for_Best_Actress_–_Television_Series_Musical_or_Comedy?
# wrong answer incoming
# False
# 0.00038742048900000024
# Question: 13
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# 0.0003486784401000002
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# 0.0003138105960900002
# Question: 15
# Does the thing you are looking for have the attribute: award People's_Choice_Award_for_Favorite_Female_Artist?
# True
# 0.0002824295364810002
# Question: 16
# Does the thing you are looking for have the attribute: award Gracie_Awards?
# True
# 0.0002541865828329002
# Question: 17
# Does the thing you are looking for have the attribute: award Guys_Choice?
# True
# 0.00022876792454961018
# Question: 18
# Does the thing you are looking for have the attribute: award Logie_Award_for_Most_Popular_Actress?
# True
# 0.00020589113209464917
# Question: 19
# Does the thing you are looking for have the attribute: award People's_Choice_Award_for_Favorite_Country_Artist?
# True
# 0.00018530201888518425
# Question: 20
# Does the thing you are looking for have the attribute: award People_Magazine_Awards?
# True
# 0.00016677181699666584
# The Answer is:  http://yago-knowledge.org/resource/Jennifer_Aniston With a Probability of:  0.00016677181699666584
# <http://yago-knowledge.org/resource/Jennifer_Aniston>
#
#  <http://yago-knowledge.org/resource/George_W._Bush>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# 0.9
# Question: 2
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 0.81
# Question: 3
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# 0.7290000000000001
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# wrong answer incoming
# True
# 0.0729
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# 0.06561
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# 0.059049000000000004
# Question: 7
# Does the thing you are looking for have the attribute: award All-NBA_Team?
# wrong answer incoming
# True
# 0.005904900000000001
# Question: 8
# Does the thing you are looking for have the attribute: award NBA_All-Rookie_Team?
# False
# 0.005314410000000001
# Question: 9
# Does the thing you are looking for have the attribute: birthPlace Philadelphia?
# False
# 0.0047829690000000015
# Question: 10
# Does the thing you are looking for have the attribute: award Best_NBA_Player_ESPY_Award?
# False
# 0.004304672100000001
# Question: 11
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# True
# 0.0038742048900000012
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Statesman?
# wrong answer incoming
# False
# 0.00038742048900000013
# Question: 13
# Does the thing you are looking for have the attribute: memberOf Republican_Party_(United_States)?
# True
# 0.0003486784401000001
# Question: 14
# Does the thing you are looking for have the attribute: award Golden_Raspberry_Award_for_Worst_Supporting_Actor?
# False
# 0.0003138105960900001
# Question: 15
# Does the thing you are looking for have the attribute: award Doublespeak_Award?
# True
# 0.0002824295364810001
# Question: 16
# Does the thing you are looking for have the attribute: award Golden_Raspberry_Award_for_Worst_Actor?
# True
# 0.0002541865828329001
# Question: 17
# Does the thing you are looking for have the attribute: award National_Defense_Service_Medal?
# True
# 0.0002287679245496101
# Question: 18
# Does the thing you are looking for have the attribute: alumniOf Phillips_Academy?
# True
# 0.0002058911320946491
# Question: 19
# Does the thing you are looking for have the attribute: knowsLanguage American_English?
# True
# 0.00018530201888518417
# Question: 20
# Does the thing you are looking for have the attribute: givenName George_(given_name)?
# True
# 0.00016677181699666576
# The Answer is:  http://yago-knowledge.org/resource/George_W._Bush With a Probability of:  0.00016677181699666576
# <http://yago-knowledge.org/resource/George_W._Bush>
#
#  <http://yago-knowledge.org/resource/Prince_(musician)>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# 0.9
# Question: 2
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 0.81
# Question: 3
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# wrong answer incoming
# True
# 0.08100000000000002
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# False
# 0.07290000000000002
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# True
# 0.06561000000000002
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# True
# 0.05904900000000002
# Question: 7
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# 0.05314410000000002
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# True
# 0.04782969000000002
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Character_actor?
# wrong answer incoming
# True
# 0.004782969000000002
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# 0.004304672100000002
# Question: 11
# Does the thing you are looking for have the attribute: award Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Leading_Role?
# False
# 0.003874204890000002
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 0.003486784401000002
# Question: 13
# Does the thing you are looking for have the attribute: memberOf Republican_Party_(United_States)?
# False
# 0.003138105960900002
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# True
# 0.0028242953648100018
# Question: 15
# Does the thing you are looking for have the attribute: award Golden_Raspberry_Award_for_Worst_Original_Song?
# True
# 0.0025418658283290017
# Question: 16
# Does the thing you are looking for have the attribute: award Golden_Globe_Award_for_Best_Original_Song?
# True
# 0.0022876792454961017
# Question: 17
# Does the thing you are looking for have the attribute: award Rock_and_Roll_Hall_of_Fame?
# True
# 0.0020589113209464917
# Question: 18
# Does the thing you are looking for have the attribute: award Golden_Raspberry_Award_for_Worst_Director?
# True
# 0.0018530201888518425
# Question: 19
# Does the thing you are looking for have the attribute: award Golden_Raspberry_Award_for_Worst_Actor?
# True
# 0.0016677181699666583
# Question: 20
# Does the thing you are looking for have the attribute: hasOccupation Dancer?
# wrong answer incoming
# False
# 0.00016677181699666584
# The Answer is:  http://yago-knowledge.org/resource/Prince_(musician) With a Probability of:  0.00016677181699666584
# <http://yago-knowledge.org/resource/Prince_(musician)>
#
#  <http://yago-knowledge.org/resource/Justin_Bieber>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# 0.9
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# wrong answer incoming
# True
# 0.09000000000000001
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# 0.08100000000000002
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# 0.07290000000000002
# Question: 5
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# 0.06561000000000002
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# True
# 0.05904900000000002
# Question: 7
# Does the thing you are looking for have the attribute: nationality United_States?
# False
# 0.05314410000000002
# Question: 8
# Does the thing you are looking for have the attribute: givenName George_(given_name)?
# False
# 0.04782969000000002
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Guitarist?
# True
# 0.043046721000000024
# Question: 10
# Does the thing you are looking for have the attribute: birthPlace Liverpool?
# False
# 0.03874204890000002
# Question: 11
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# 0.03486784401000002
# Question: 12
# Does the thing you are looking for have the attribute: award Bravo_Otto?
# True
# 0.03138105960900001
# Question: 13
# Does the thing you are looking for have the attribute: award Danish_Music_Awards?
# True
# 0.028242953648100012
# Question: 14
# Does the thing you are looking for have the attribute: award IHeartRadio_MMVAs?
# True
# 0.025418658283290013
# Question: 15
# Does the thing you are looking for have the attribute: award Billboard_Music_Award?
# wrong answer incoming
# False
# 0.0025418658283290017
# Question: 16
# Does the thing you are looking for have the attribute: nationality Canada?
# True
# 0.0022876792454961017
# Question: 17
# Does the thing you are looking for have the attribute: award MTV_Video_Music_Brazil?
# True
# 0.0020589113209464917
# Question: 18
# Does the thing you are looking for have the attribute: hasOccupation Lyricist?
# wrong answer incoming
# False
# 0.00020589113209464917
# Question: 19
# Does the thing you are looking for have the attribute: hasOccupation Child_actor?
# True
# 0.00018530201888518425
# Question: 20
# Does the thing you are looking for have the attribute: award NME_Awards?
# True
# 0.00016677181699666584
# The Answer is:  http://yago-knowledge.org/resource/Justin_Bieber With a Probability of:  0.00016677181699666584
# <http://yago-knowledge.org/resource/Justin_Bieber>
#
#  <http://yago-knowledge.org/resource/Drake_(musician)>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# 0.9
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# 0.81
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_States?
# False
# 0.7290000000000001
# Question: 4
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# wrong answer incoming
# True
# 0.0729
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 0.06561
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# 0.059049000000000004
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# wrong answer incoming
# False
# 0.005904900000000001
# Question: 8
# Does the thing you are looking for have the attribute: award Order_of_the_Elephant?
# False
# 0.005314410000000001
# Question: 9
# Does the thing you are looking for have the attribute: award Presidential_Medal_of_Freedom?
# False
# 0.0047829690000000015
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# 0.004304672100000001
# Question: 11
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# False
# 0.0038742048900000012
# Question: 12
# Does the thing you are looking for have the attribute: knowsLanguage German_language?
# False
# 0.003486784401000001
# Question: 13
# Does the thing you are looking for have the attribute: award Academy_Award_for_Best_Actress?
# False
# 0.003138105960900001
# Question: 14
# Does the thing you are looking for have the attribute: award BIFA_Award_for_Best_Performance_by_an_Actor_in_a_British_Independent_Film?
# False
# 0.002824295364810001
# Question: 15
# Does the thing you are looking for have the attribute: hasOccupation Guitarist?
# False
# 0.002541865828329001
# Question: 16
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# 0.002287679245496101
# Question: 17
# Does the thing you are looking for have the attribute: award Albert_Medal_(Royal_Society_of_Arts)?
# wrong answer incoming
# True
# 0.0002287679245496101
# Question: 18
# Does the thing you are looking for have the attribute: award Order_of_the_Garter?
# False
# 0.0002058911320946491
# Question: 19
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# 0.00018530201888518417
# Question: 20
# Does the thing you are looking for have the attribute: knowsLanguage French_language?
# False
# 0.00016677181699666576
# The Answer is:  http://yago-knowledge.org/resource/Rachel_Weisz With a Probability of:  0.00016677181699666584
# <http://yago-knowledge.org/resource/Drake_(musician)>
#
#  <http://yago-knowledge.org/resource/Heath_Ledger>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# wrong answer incoming
# False
# 0.1
# Question: 2
# Does the thing you are looking for have the attribute: nationality United_States?
# False
# 0.09000000000000001
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# 0.08100000000000002
# Question: 4
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# 0.07290000000000002
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# wrong answer incoming
# True
# 0.007290000000000002
# Question: 6
# Does the thing you are looking for have the attribute: memberOf American_Academy_of_Arts_and_Sciences?
# False
# 0.006561000000000002
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Statesman?
# False
# 0.005904900000000002
# Question: 8
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# 0.005314410000000002
# Question: 9
# Does the thing you are looking for have the attribute: award Time_Person_of_the_Year?
# False
# 0.004782969000000002
# Question: 10
# Does the thing you are looking for have the attribute: knowsLanguage German_language?
# False
# 0.004304672100000002
# Question: 11
# Does the thing you are looking for have the attribute: award Order_of_Saint_John_(chartered_1888)?
# False
# 0.003874204890000002
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# 0.003486784401000002
# Question: 13
# Does the thing you are looking for have the attribute: hasOccupation Playwright?
# False
# 0.003138105960900002
# Question: 14
# Does the thing you are looking for have the attribute: homeLocation New_York_City?
# False
# 0.0028242953648100018
# Question: 15
# Does the thing you are looking for have the attribute: givenName Alexander?
# wrong answer incoming
# True
# 0.0002824295364810002
# Question: 16
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# 0.0002541865828329002
# Question: 17
# Does the thing you are looking for have the attribute: award Presidential_Medal_of_Freedom?
# False
# 0.00022876792454961018
# Question: 18
# Does the thing you are looking for have the attribute: knowsLanguage French_language?
# False
# 0.00020589113209464917
# Question: 19
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# 0.00018530201888518425
# Question: 20
# Does the thing you are looking for have the attribute: memberOf Republican_Party_(United_States)?
# False
# 0.00016677181699666584
# The Answer is:  http://yago-knowledge.org/resource/Alexander_the_Great With a Probability of:  0.013508517176729932
# <http://yago-knowledge.org/resource/Heath_Ledger>
#
#  <http://yago-knowledge.org/resource/John_Krasinski>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# 0.9
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# True
# 0.81
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# True
# 0.7290000000000001
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# True
# 0.6561000000000001
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Character_actor?
# False
# 0.5904900000000002
# Question: 6
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# False
# 0.5314410000000002
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# wrong answer incoming
# False
# 0.05314410000000002
# Question: 8
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 0.04782969000000002
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# 0.043046721000000024
# Question: 10
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# 0.03874204890000002
# Question: 11
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# True
# 0.03486784401000002
# Question: 12
# Does the thing you are looking for have the attribute: alumniOf Brown_University?
# True
# 0.03138105960900001
# Question: 13
# Does the thing you are looking for have the attribute: award Theatre_World_Award?
# wrong answer incoming
# False
# 0.0031381059609000015
# Question: 14
# Does the thing you are looking for have the attribute: givenName John_(given_name)?
# True
# 0.0028242953648100013
# Question: 15
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# 0.0025418658283290012
# Question: 16
# Does the thing you are looking for have the attribute: award MTV_Movie_Award_for_Best_On-Screen_Duo?
# False
# 0.0022876792454961012
# Question: 17
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# wrong answer incoming
# True
# 0.00022876792454961013
# Question: 18
# Does the thing you are looking for have the attribute: nationality British_Raj?
# False
# 0.00020589113209464911
# Question: 19
# Does the thing you are looking for have the attribute: hasOccupation Businessperson?
# False
# 0.0001853020188851842
# Question: 20
# Does the thing you are looking for have the attribute: award Golden_Globe_Award_for_Best_Supporting_Actor_–_Series,_Miniseries_or_Television_Film?
# False
# 0.0001667718169966658
# The Answer is:  http://yago-knowledge.org/resource/John_Krasinski With a Probability of:  0.0001667718169966658
# <http://yago-knowledge.org/resource/John_Krasinski>
#
#  <http://yago-knowledge.org/resource/Val_Kilmer>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# 0.9
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# True
# 0.81
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# True
# 0.7290000000000001
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# 0.6561000000000001
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# True
# 0.5904900000000002
# Question: 6
# Does the thing you are looking for have the attribute: award Golden_Globe_Award_for_Best_Actor_–_Motion_Picture_Musical_or_Comedy?
# wrong answer incoming
# True
# 0.05904900000000002
# Question: 7
# Does the thing you are looking for have the attribute: alumniOf Juilliard_School?
# True
# 0.05314410000000002
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Mime_artist?
# False
# 0.04782969000000002
# Question: 9
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# 0.043046721000000024
# Question: 10
# Does the thing you are looking for have the attribute: givenName Edward?
# True
# 0.03874204890000002
# Question: 11
# Does the thing you are looking for have the attribute: birthPlace Los_Angeles?
# True
# 0.03486784401000002
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Poet?
# True
# 0.03138105960900001
# Question: 13
# Does the thing you are looking for have the attribute: award Golden_Globe_Cecil_B._DeMille_Award?
# False
# 0.028242953648100012
# Question: 14
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# wrong answer incoming
# True
# 0.0028242953648100013
# Question: 15
# Does the thing you are looking for have the attribute: award Academy_Award_for_Best_Actor?
# False
# 0.0025418658283290012
# Question: 16
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# 0.0022876792454961012
# Question: 17
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# wrong answer incoming
# True
# 0.00022876792454961013
# Question: 18
# Does the thing you are looking for have the attribute: hasOccupation Dancer?
# False
# 0.00020589113209464911
# Question: 19
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# 0.0001853020188851842
# Question: 20
# Does the thing you are looking for have the attribute: alumniOf Lee_Strasberg_Theatre_and_Film_Institute?
# False
# 0.0001667718169966658
# The Answer is:  http://yago-knowledge.org/resource/Val_Kilmer With a Probability of:  0.0001667718169966658
# <http://yago-knowledge.org/resource/Val_Kilmer>
#
#  <http://yago-knowledge.org/resource/Brad_Pitt>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# 0.9
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# wrong answer incoming
# False
# 0.09000000000000001
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 0.08100000000000002
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# False
# 0.07290000000000002
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# wrong answer incoming
# True
# 0.007290000000000002
# Question: 6
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# True
# 0.006561000000000002
# Question: 7
# Does the thing you are looking for have the attribute: award Primetime_Emmy_Award_for_Outstanding_Lead_Actress_in_a_Comedy_Series?
# wrong answer incoming
# True
# 0.0006561000000000002
# Question: 8
# Does the thing you are looking for have the attribute: birthPlace Oak_Park,_Illinois?
# False
# 0.0005904900000000002
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Businessperson?
# False
# 0.0005314410000000001
# Question: 10
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# 0.0004782969000000001
# Question: 11
# Does the thing you are looking for have the attribute: award Golden_Globe_Award_for_Best_Actress_–_Motion_Picture_Comedy_or_Musical?
# False
# 0.0004304672100000001
# Question: 12
# Does the thing you are looking for have the attribute: award Theatre_World_Award?
# False
# 0.0003874204890000001
# Question: 13
# Does the thing you are looking for have the attribute: award Grammy_Lifetime_Achievement_Award?
# False
# 0.00034867844010000006
# Question: 14
# Does the thing you are looking for have the attribute: alumniOf Columbia_University?
# False
# 0.00031381059609000004
# Question: 15
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# 0.00028242953648100003
# Question: 16
# Does the thing you are looking for have the attribute: hasOccupation Executive_producer?
# True
# 0.00025418658283290005
# Question: 17
# Does the thing you are looking for have the attribute: birthPlace Sherman_Oaks,_Los_Angeles?
# False
# 0.00022876792454961005
# Question: 18
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# True
# 0.00020589113209464906
# Question: 19
# Does the thing you are looking for have the attribute: award Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture?
# True
# 0.00018530201888518417
# Question: 20
# Does the thing you are looking for have the attribute: givenName William?
# True
# 0.00016677181699666576
# The Answer is:  http://yago-knowledge.org/resource/Brad_Pitt With a Probability of:  0.00016677181699666576
# <http://yago-knowledge.org/resource/Brad_Pitt>
#
#  <http://yago-knowledge.org/resource/Barack_Obama>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# 0.9
# Question: 2
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 0.81
# Question: 3
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# True
# 0.7290000000000001
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# True
# 0.6561000000000001
# Question: 5
# Does the thing you are looking for have the attribute: memberOf American_Academy_of_Arts_and_Sciences?
# True
# 0.5904900000000002
# Question: 6
# Does the thing you are looking for have the attribute: award Ellis_Island_Medal_of_Honor?
# False
# 0.5314410000000002
# Question: 7
# Does the thing you are looking for have the attribute: award Presidential_Medal_of_Freedom?
# False
# 0.47829690000000014
# Question: 8
# Does the thing you are looking for have the attribute: award Order_of_the_British_Empire?
# True
# 0.43046721000000016
# Question: 9
# Does the thing you are looking for have the attribute: award Grammy_Award_for_Best_Spoken_Word_Album?
# True
# 0.38742048900000015
# Question: 10
# Does the thing you are looking for have the attribute: alumniOf Occidental_College?
# True
# 0.34867844010000015
# Question: 11
# Does the thing you are looking for have the attribute: award Order_of_King_Abdulaziz?
# wrong answer incoming
# False
# 0.03486784401000002
# Question: 12
# Does the thing you are looking for have the attribute: award Time_Person_of_the_Year?
# True
# 0.03138105960900001
# Question: 13
# Does the thing you are looking for have the attribute: memberOf American_Philosophical_Society?
# wrong answer incoming
# False
# 0.0031381059609000015
# Question: 14
# Does the thing you are looking for have the attribute: alumniOf Harvard_College?
# False
# 0.0028242953648100013
# Question: 15
# Does the thing you are looking for have the attribute: alumniOf Columbia_University?
# True
# 0.0025418658283290012
# Question: 16
# Does the thing you are looking for have the attribute: knowsLanguage German_language?
# False
# 0.0022876792454961012
# Question: 17
# Does the thing you are looking for have the attribute: hasOccupation Statesman?
# wrong answer incoming
# False
# 0.00022876792454961013
# Question: 18
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# 0.00020589113209464911
# Question: 19
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 0.0001853020188851842
# Question: 20
# Does the thing you are looking for have the attribute: homeLocation San_Francisco?
# False
# 0.0001667718169966658
# The Answer is:  http://yago-knowledge.org/resource/Barack_Obama With a Probability of:  0.0001667718169966658
# <http://yago-knowledge.org/resource/Barack_Obama>
#
#  <http://yago-knowledge.org/resource/Bill_Clinton>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# 0.9
# Question: 2
# Does the thing you are looking for have the attribute: nationality United_States?
# wrong answer incoming
# False
# 0.09000000000000001
# Question: 3
# Does the thing you are looking for have the attribute: nationality United_Kingdom?
# False
# 0.08100000000000002
# Question: 4
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# 0.07290000000000002
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# wrong answer incoming
# False
# 0.007290000000000002
# Question: 6
# Does the thing you are looking for have the attribute: knowsLanguage German_language?
# True
# 0.006561000000000002
# Question: 7
# Does the thing you are looking for have the attribute: knowsLanguage French_language?
# False
# 0.005904900000000002
# Question: 8
# Does the thing you are looking for have the attribute: nationality Switzerland?
# False
# 0.005314410000000002
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# 0.004782969000000002
# Question: 10
# Does the thing you are looking for have the attribute: award Order_of_the_Elephant?
# wrong answer incoming
# True
# 0.00047829690000000027
# Question: 11
# Does the thing you are looking for have the attribute: award Time_Person_of_the_Year?
# False
# 0.00043046721000000027
# Question: 12
# Does the thing you are looking for have the attribute: award Albert_Medal_(Royal_Society_of_Arts)?
# False
# 0.00038742048900000024
# Question: 13
# Does the thing you are looking for have the attribute: award Presidential_Medal_of_Freedom?
# True
# 0.0003486784401000002
# Question: 14
# Does the thing you are looking for have the attribute: award Philadelphia_Liberty_Medal?
# True
# 0.0003138105960900002
# Question: 15
# Does the thing you are looking for have the attribute: award Order_of_Lenin?
# False
# 0.0002824295364810002
# Question: 16
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# True
# 0.0002541865828329002
# Question: 17
# Does the thing you are looking for have the attribute: award Freedom_Award?
# True
# 0.00022876792454961018
# Question: 18
# Does the thing you are looking for have the attribute: award NAACP_Image_Award_–_President's_Award?
# True
# 0.00020589113209464917
# Question: 19
# Does the thing you are looking for have the attribute: award Order_of_the_State_of_Republic_of_Turkey?
# True
# 0.00018530201888518425
# Question: 20
# Does the thing you are looking for have the attribute: award Citizen_of_the_World?
# True
# 0.00016677181699666584
# The Answer is:  http://yago-knowledge.org/resource/Bill_Clinton With a Probability of:  0.00016677181699666584
# <http://yago-knowledge.org/resource/Bill_Clinton>
#
#  <http://yago-knowledge.org/resource/Donald_Trump>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# 0.9
# Question: 2
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 0.81
# Question: 3
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# 0.7290000000000001
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# wrong answer incoming
# True
# 0.0729
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# wrong answer incoming
# True
# 0.007290000000000001
# Question: 6
# Does the thing you are looking for have the attribute: award Golden_Raspberry_Award_for_Worst_Actor?
# False
# 0.006561000000000002
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# 0.005904900000000002
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 0.005314410000000002
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Businessperson?
# False
# 0.004782969000000002
# Question: 10
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# 0.004304672100000002
# Question: 11
# Does the thing you are looking for have the attribute: award All-NBA_Team?
# False
# 0.003874204890000002
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# 0.003486784401000002
# Question: 13
# Does the thing you are looking for have the attribute: award MTV_Movie_Award_for_Best_On-Screen_Duo?
# False
# 0.003138105960900002
# Question: 14
# Does the thing you are looking for have the attribute: givenName Matthew_(given_name)?
# False
# 0.0028242953648100018
# Question: 15
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# 0.0025418658283290017
# Question: 16
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# True
# 0.0022876792454961017
# Question: 17
# Does the thing you are looking for have the attribute: hasOccupation Statesman?
# False
# 0.0020589113209464917
# Question: 18
# Does the thing you are looking for have the attribute: memberOf Republican_Party_(United_States)?
# True
# 0.0018530201888518425
# Question: 19
# Does the thing you are looking for have the attribute: award Golden_Raspberry_Award_for_Worst_Supporting_Actor?
# True
# 0.0016677181699666583
# Question: 20
# Does the thing you are looking for have the attribute: award Order_of_King_Abdulaziz?
# wrong answer incoming
# False
# 0.00016677181699666584
# The Answer is:  http://yago-knowledge.org/resource/Donald_Trump With a Probability of:  0.00016677181699666584
# <http://yago-knowledge.org/resource/Donald_Trump>
#
#  <http://yago-knowledge.org/resource/Jimmy_Carter>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# 0.9
# Question: 2
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 0.81
# Question: 3
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# True
# 0.7290000000000001
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# True
# 0.6561000000000001
# Question: 5
# Does the thing you are looking for have the attribute: memberOf American_Academy_of_Arts_and_Sciences?
# True
# 0.5904900000000002
# Question: 6
# Does the thing you are looking for have the attribute: award Ellis_Island_Medal_of_Honor?
# True
# 0.5314410000000002
# Question: 7
# Does the thing you are looking for have the attribute: memberOf American_Legion?
# wrong answer incoming
# False
# 0.05314410000000002
# Question: 8
# Does the thing you are looking for have the attribute: award Freedom_Award?
# False
# 0.04782969000000002
# Question: 9
# Does the thing you are looking for have the attribute: award Philadelphia_Liberty_Medal?
# True
# 0.043046721000000024
# Question: 10
# Does the thing you are looking for have the attribute: award St._George's_Order_of_Victory?
# False
# 0.03874204890000002
# Question: 11
# Does the thing you are looking for have the attribute: award National_Defense_Service_Medal?
# True
# 0.03486784401000002
# Question: 12
# Does the thing you are looking for have the attribute: award Order_of_Manuel_Amador_Guerrero?
# True
# 0.03138105960900001
# Question: 13
# Does the thing you are looking for have the attribute: givenName Earl_(given_name)?
# True
# 0.028242953648100012
# Question: 14
# Does the thing you are looking for have the attribute: knowsLanguage Spanish_language?
# True
# 0.025418658283290013
# Question: 15
# Does the thing you are looking for have the attribute: award Delta_Prize_for_Global_Understanding?
# True
# 0.022876792454961013
# Question: 16
# Does the thing you are looking for have the attribute: award American_Campaign_Medal?
# True
# 0.020589113209464913
# Question: 17
# Does the thing you are looking for have the attribute: award Félix_Houphouët-Boigny_Peace_Prize?
# wrong answer incoming
# False
# 0.0020589113209464912
# Question: 18
# Does the thing you are looking for have the attribute: award Order_of_the_Nile?
# True
# 0.001853020188851842
# Question: 19
# Does the thing you are looking for have the attribute: award United_Nations_Prize_in_the_Field_of_Human_Rights?
# wrong answer incoming
# False
# 0.00018530201888518422
# Question: 20
# Does the thing you are looking for have the attribute: award Presidential_Medal_of_Freedom?
# True
# 0.00016677181699666582
# The Answer is:  http://yago-knowledge.org/resource/Jimmy_Carter With a Probability of:  0.00016677181699666582
# <http://yago-knowledge.org/resource/Jimmy_Carter>
#
#  <http://yago-knowledge.org/resource/Martin_Luther_King_Jr.>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# 0.9
# Question: 2
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 0.81
# Question: 3
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# wrong answer incoming
# True
# 0.08100000000000002
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# False
# 0.07290000000000002
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# wrong answer incoming
# True
# 0.007290000000000002
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# False
# 0.006561000000000002
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Executive_producer?
# False
# 0.005904900000000002
# Question: 8
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# False
# 0.005314410000000002
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 0.004782969000000002
# Question: 10
# Does the thing you are looking for have the attribute: award Presidential_Medal_of_Freedom?
# True
# 0.004304672100000002
# Question: 11
# Does the thing you are looking for have the attribute: award Grammy_Legend_Award?
# False
# 0.003874204890000002
# Question: 12
# Does the thing you are looking for have the attribute: memberOf American_Academy_of_Arts_and_Sciences?
# True
# 0.003486784401000002
# Question: 13
# Does the thing you are looking for have the attribute: hasOccupation Statesman?
# False
# 0.003138105960900002
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# True
# 0.0028242953648100018
# Question: 15
# Does the thing you are looking for have the attribute: birthPlace Atlanta?
# True
# 0.0025418658283290017
# Question: 16
# Does the thing you are looking for have the attribute: award Jawaharlal_Nehru_Award?
# True
# 0.0022876792454961017
# Question: 17
# Does the thing you are looking for have the attribute: award Time_Person_of_the_Year?
# True
# 0.0020589113209464917
# Question: 18
# Does the thing you are looking for have the attribute: award Pacem_in_Terris_Award?
# True
# 0.0018530201888518425
# Question: 19
# Does the thing you are looking for have the attribute: award Order_of_the_Companions_of_O._R._Tambo?
# True
# 0.0016677181699666583
# Question: 20
# Does the thing you are looking for have the attribute: award United_Nations_Prize_in_the_Field_of_Human_Rights?
# wrong answer incoming
# False
# 0.00016677181699666584
# The Answer is:  http://yago-knowledge.org/resource/Martin_Luther_King_Jr. With a Probability of:  0.00016677181699666584
# <http://yago-knowledge.org/resource/Martin_Luther_King_Jr.>
#
#  <http://yago-knowledge.org/resource/Ronald_Reagan>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# wrong answer incoming
# False
# 0.1
# Question: 2
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 0.09000000000000001
# Question: 3
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# 0.08100000000000002
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# wrong answer incoming
# True
# 0.008100000000000001
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# False
# 0.007290000000000001
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# 0.006561000000000002
# Question: 7
# Does the thing you are looking for have the attribute: award All-NBA_Team?
# False
# 0.005904900000000002
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# True
# 0.005314410000000002
# Question: 9
# Does the thing you are looking for have the attribute: hasOccupation Statesman?
# wrong answer incoming
# False
# 0.0005314410000000002
# Question: 10
# Does the thing you are looking for have the attribute: memberOf Republican_Party_(United_States)?
# True
# 0.0004782969000000002
# Question: 11
# Does the thing you are looking for have the attribute: award Gaming_Hall_of_Fame?
# False
# 0.0004304672100000002
# Question: 12
# Does the thing you are looking for have the attribute: award Doublespeak_Award?
# True
# 0.0003874204890000002
# Question: 13
# Does the thing you are looking for have the attribute: award Golden_Raspberry_Award_for_Worst_Actor?
# False
# 0.00034867844010000017
# Question: 14
# Does the thing you are looking for have the attribute: award Golden_Raspberry_Award_for_Worst_Supporting_Actor?
# False
# 0.00031381059609000015
# Question: 15
# Does the thing you are looking for have the attribute: memberOf American_Legion?
# True
# 0.00028242953648100014
# Question: 16
# Does the thing you are looking for have the attribute: award Presidential_Medal_of_Freedom?
# True
# 0.00025418658283290016
# Question: 17
# Does the thing you are looking for have the attribute: award Order_of_the_Bath?
# True
# 0.00022876792454961016
# Question: 18
# Does the thing you are looking for have the attribute: award Order_of_the_White_Eagle_(Poland)?
# True
# 0.00020589113209464914
# Question: 19
# Does the thing you are looking for have the attribute: award Order_of_the_White_Lion?
# True
# 0.00018530201888518422
# Question: 20
# Does the thing you are looking for have the attribute: award Congressional_Gold_Medal?
# True
# 0.00016677181699666582
# The Answer is:  http://yago-knowledge.org/resource/Ronald_Reagan With a Probability of:  0.00016677181699666582
# <http://yago-knowledge.org/resource/Ronald_Reagan>
#
#  <http://yago-knowledge.org/resource/Matthew_Perry>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# False
# 0.9
# Question: 2
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 0.81
# Question: 3
# Does the thing you are looking for have the attribute: memberOf Democratic_Party_(United_States)?
# False
# 0.7290000000000001
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# True
# 0.6561000000000001
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# wrong answer incoming
# False
# 0.06561000000000002
# Question: 6
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# True
# 0.05904900000000002
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 0.05314410000000002
# Question: 8
# Does the thing you are looking for have the attribute: birthPlace Oak_Park,_Illinois?
# False
# 0.04782969000000002
# Question: 9
# Does the thing you are looking for have the attribute: memberOf American_Academy_of_Arts_and_Sciences?
# False
# 0.043046721000000024
# Question: 10
# Does the thing you are looking for have the attribute: award All-NBA_Team?
# False
# 0.03874204890000002
# Question: 11
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# wrong answer incoming
# False
# 0.003874204890000002
# Question: 12
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# 0.003486784401000002
# Question: 13
# Does the thing you are looking for have the attribute: hasOccupation Poet?
# False
# 0.003138105960900002
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Politician?
# False
# 0.0028242953648100018
# Question: 15
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# False
# 0.0025418658283290017
# Question: 16
# Does the thing you are looking for have the attribute: award Best_NBA_Player_ESPY_Award?
# False
# 0.0022876792454961017
# Question: 17
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# 0.0020589113209464917
# Question: 18
# Does the thing you are looking for have the attribute: homeLocation Los_Angeles?
# True
# 0.0018530201888518425
# Question: 19
# Does the thing you are looking for have the attribute: nationality Canada?
# True
# 0.0016677181699666583
# Question: 20
# Does the thing you are looking for have the attribute: givenName Matthew_(given_name)?
# wrong answer incoming
# False
# 0.00016677181699666584
# The Answer is:  http://yago-knowledge.org/resource/Matthew_Perry With a Probability of:  0.00016677181699666584
# <http://yago-knowledge.org/resource/Matthew_Perry>
#
#  <http://yago-knowledge.org/resource/Robert_Downey_Jr.>
# Question: 1
# Does the thing you are looking for have the attribute: hasOccupation Actor?
# True
# 0.9
# Question: 2
# Does the thing you are looking for have the attribute: hasOccupation Film_producer?
# True
# 0.81
# Question: 3
# Does the thing you are looking for have the attribute: hasOccupation Screenwriter?
# True
# 0.7290000000000001
# Question: 4
# Does the thing you are looking for have the attribute: hasOccupation Film_director?
# True
# 0.6561000000000001
# Question: 5
# Does the thing you are looking for have the attribute: hasOccupation Character_actor?
# False
# 0.5904900000000002
# Question: 6
# Does the thing you are looking for have the attribute: knowsLanguage English_language?
# True
# 0.5314410000000002
# Question: 7
# Does the thing you are looking for have the attribute: hasOccupation Writer?
# False
# 0.47829690000000014
# Question: 8
# Does the thing you are looking for have the attribute: hasOccupation Singer-songwriter?
# True
# 0.43046721000000016
# Question: 9
# Does the thing you are looking for have the attribute: homeLocation Malibu,_California?
# wrong answer incoming
# False
# 0.04304672100000002
# Question: 10
# Does the thing you are looking for have the attribute: award Rock_and_Roll_Hall_of_Fame?
# wrong answer incoming
# True
# 0.004304672100000002
# Question: 11
# Does the thing you are looking for have the attribute: nationality United_States?
# True
# 0.003874204890000002
# Question: 12
# Does the thing you are looking for have the attribute: award Golden_Globe_Award_for_Best_Original_Song?
# False
# 0.003486784401000002
# Question: 13
# Does the thing you are looking for have the attribute: hasOccupation Songwriter?
# False
# 0.003138105960900002
# Question: 14
# Does the thing you are looking for have the attribute: hasOccupation Guitarist?
# False
# 0.0028242953648100018
# Question: 15
# Does the thing you are looking for have the attribute: award Golden_Globe_Award_for_Best_Actor_–_Motion_Picture_Musical_or_Comedy?
# True
# 0.0025418658283290017
# Question: 16
# Does the thing you are looking for have the attribute: homeLocation California?
# wrong answer incoming
# False
# 0.00025418658283290016
# Question: 17
# Does the thing you are looking for have the attribute: hasOccupation Stage_actor?
# False
# 0.00022876792454961016
# Question: 18
# Does the thing you are looking for have the attribute: homeLocation New_York_City?
# True
# 0.00020589113209464914
# Question: 19
# Does the thing you are looking for have the attribute: award Golden_Globe_Award_for_Best_Supporting_Actor_–_Series,_Miniseries_or_Television_Film?
# True
# 0.00018530201888518422
# Question: 20
# Does the thing you are looking for have the attribute: award BAFTA_Award_for_Best_Actor_in_a_Leading_Role?
# True
# 0.00016677181699666582
# The Answer is:  http://yago-knowledge.org/resource/Robert_Downey_Jr. With a Probability of:  0.00016677181699666582
# <http://yago-knowledge.org/resource/Robert_Downey_Jr.>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-275cfd73089e> in <module>
#       1 for i in list_losses:
# ----> 2     first.append(i[0])
#       3     first2.append(i[1])
#       4     first3.append(i[2])
#       5     first4.append(i[3])
#
# NameError: name 'first' is not defined

# %%
for i in Entrop_over_game: 
    print(sum(i))

# %%
import matplotlib.pyplot as plt
import numpy as np

xax = numpy.array(range(0,134))
for i in dis_over_time:
    yax=[]
    for j in i:
        yax.append(j)
    plt.plot(xax, yax)
plt.show

color = plt.cm.rainbow(np.linspace(0, 1, len(dis_over_time)))
for i, c in zip(range(len(dis_over_time)), color):
    yax=dis_over_time[i]
    plt.plot(xax, yax, c=c)

# %%
yax = []
xax = numpy.array(range(0,134))

for j in range(9):
    yax = []
    for i in analyse_dis[j].values():
        yax.append(i)
    plt.plot(xax, yax)
    plt.show()

# %%
from random import randint
import random
import math
import time 

possibleObj, possiblePred, count = findSplits()
popularEntities =  popentities("\n".join(PosAttr),"")
Distribution = prepareProps(popularEntities)


bestSplit=-1
indexBestSplit = -1
#branches = range(2,250)
#for i in random.sample(branches, 30): 
for i in range(25):
    #Fix The nummerical thing here::: (skip over i if nummer)
    if str('<' + str(possiblePred[i]) +'> <'+str(possibleObj[i])+ '>') in AttrHistory:
        continue
    else:
        Yes, No = findPosAndNeg(possibleObj, possiblePred, i)
        OccurenceYes=len(Yes)
        OccurenceNo=len(No)
        WeightYes=0
        WeightNo=0
        for y in Yes:
            WeightYes+=Distribution[y]
        for n in No:
            WeightNo+=Distribution[n]
        SumWeights=WeightYes+WeightNo
        ProbabilityYes=WeightYes/SumWeights
        ProbabilityNo=WeightNo/SumWeights
        Entropy = - (ProbabilityYes * math.log(ProbabilityYes+0.0001,2) + ProbabilityNo * math.log(ProbabilityNo+0.0001,2))
        print(Entropy, possiblePred[i], possibleObj[i])
        #print(str(possiblePred[i]) +'> <'+str(possibleObj[i]), Entropy)
        if Entropy > bestSplit:
            bestSplit=Entropy
            indexBestSplit=i
#print(bestSplit, possibleObj[indexBestSplit], possiblePred[indexBestSplit])
print(bestSplit, indexBestSplit)

# %%
list_wins
# Out:
# [[True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True],
#  [True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False],
#  [True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False],
#  [True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True],
#  [True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True],
#  [True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True],
#  [True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True],
#  [True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True],
#  [True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True],
#  [True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True],
#  [True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True],
#  [True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True],
#  [True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True],
#  [True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True],
#  [True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False],
#  [True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True],
#  [False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True],
#  [True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False],
#  [True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True],
#  [True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True],
#  [True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True],
#  [True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True],
#  [True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True],
#  [True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True],
#  [True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True],
#  [True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True],
#  [True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False],
#  [True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False],
#  [True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True],
#  [True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True],
#  [True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False],
#  [True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False],
#  [True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True],
#  [True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True],
#  [False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True],
#  [True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True],
#  [True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True]]
